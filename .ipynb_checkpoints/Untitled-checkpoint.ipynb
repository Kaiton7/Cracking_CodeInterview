# %%
#問題進捗の記録を残していく

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
number_probrem = np.array([7,10])
x=["1","2"]

# %%
plt.xlabel("日にち")
plt.ylabel("解いた問題数")
plt.bar(x,number_probrem)
